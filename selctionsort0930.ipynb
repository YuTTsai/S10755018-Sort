# %% [markdown]
# <a href="https://colab.research.google.com/github/YuTTsai/S10755018-Sort/blob/master/selctionsort0930.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Selection sort (選擇排序)

# %%
def Selction_Sort(datas):
    for i in range(len(datas)-1):
        min = i # 第一次選從第一個數開始,第二次從第二個數開始
        for j in range(i+1, len(datas)):    # 用記錄的max數與其他的比較
            if datas[j] < datas[min]:
                min = j

        datas[i], datas[min] = datas[min], datas[i]

        print(datas)
        print('---'*20)
    return datas


if __name__ == '__main__':
    import random
    a = list(range(16))
    random.shuffle(a)
    print(a)
    a = Selction_Sort(a)
    print(a)
# Out:
# [4, 11, 5, 15, 12, 13, 7, 9, 1, 14, 8, 6, 2, 3, 10, 0]
# [0, 11, 5, 15, 12, 13, 7, 9, 1, 14, 8, 6, 2, 3, 10, 4]
# ------------------------------------------------------------
# [0, 1, 5, 15, 12, 13, 7, 9, 11, 14, 8, 6, 2, 3, 10, 4]
# ------------------------------------------------------------
# [0, 1, 2, 15, 12, 13, 7, 9, 11, 14, 8, 6, 5, 3, 10, 4]
# ------------------------------------------------------------
# [0, 1, 2, 3, 12, 13, 7, 9, 11, 14, 8, 6, 5, 15, 10, 4]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 13, 7, 9, 11, 14, 8, 6, 5, 15, 10, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 7, 9, 11, 14, 8, 6, 13, 15, 10, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 6, 9, 11, 14, 8, 7, 13, 15, 10, 12]
# ------------------------------------------------------------
# [0, 1, 2, 3, 4, 5, 6, 7, 11, 14, 8, 9, 13, 15, 10, 12]
# ...

# %% [markdown]
# 請加入註解
